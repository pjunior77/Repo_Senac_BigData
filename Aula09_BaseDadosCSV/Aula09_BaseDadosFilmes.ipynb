# %%
import pandas as pd

#df = pd.read_csv('world_imdb_movies_top_movies_per_year.csv', sep=',', Encoding='latin1')
#df = pd.read_csv('world_imdb_movies_top_movies_per_year.csv', sep=',')
df = pd.read_csv('world_imdb_movies_top_movies_per_year.csv')

# %%
df.head(10)

#Colunas a selecionar para fazer uma análise
##title, year, duration, rating_imdb, vote, genre, country_origin, language, wins, oscar
# Out:
#           id                               title  \
# 0  tt0073470          Strip Nude for Your Killer
# 1  tt0072764                     Carry on Behind
# 2  tt0131526  So Young, So Lovely, So Vicious...
# 3  tt0073335                            Mahogany
# 4  tt0073006                            Foreplay
# 5  tt0073343              The Man from Hong Kong
# 6  tt0073461               Night of the Seagulls
# 7  tt0073482         The Olsen Gang on the Track
# 8  tt0073208             A Woman Called Sada Abe
# 9  tt0360231                           Zinda Dil
#
#                                    link  year duration rating_mpa  \
# 0  https://www.imdb.com/title/tt0073470  1975   1h 38m  Not Rated
# 1  https://www.imdb.com/title/tt0072764  1975   1h 30m  Not Rated
# 2  https://www.imdb.com/title/tt0131526  1975   1h 30m        NaN
# 3  https://www.imdb.com/title/tt0073335  1975   1h 49m         PG
# 4  https://www.imdb.com/title/tt0073006  1975   1h 15m          R
# ...
